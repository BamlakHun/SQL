# %% [markdown]
# <a href="https://colab.research.google.com/github/BamlakHun/SQL/blob/main/SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture

# !pip install jupysql
# !pip install duckdb-engine
# !wget https://github.com/duckdb/duckdb/releases/download/v0.9.1/duckdb_cli-linux-amd64.zip
# !unzip -o duckdb_cli-linux-amd64.zip
# !wget https://duckdb.org/data/flights.csv

import duckdb
import pandas as pd

# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False
# %sql duckdb:///:default:

# %%
# !pip install ipython-sql
# !pip install duckdb-engine
# Out:
# Requirement already satisfied: ipython-sql in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (3.12.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (7.34.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (2.0.36)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (0.5.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=2.0->ipython-sql) (3.1.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: duckdb-engine in /usr/local/lib/python3.10/dist-packages (0.13.6)
# Requirement already satisfied: duckdb>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from duckdb-engine) (1.1.3)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from duckdb-engine) (24.2)
# Requirement already satisfied: sqlalchemy>=1.3.22 in /usr/local/lib/python3.10/dist-packages (from duckdb-engine) (2.0.36)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine) (3.1.1)

# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (3.12.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (7.34.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (2.0.36)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (0.5.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=2.0->ipython-sql) (3.1.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)

# %%
# !pip install duckdb-engine
# Out:
# Requirement already satisfied: duckdb-engine in /usr/local/lib/python3.10/dist-packages (0.13.6)
# Requirement already satisfied: duckdb>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from duckdb-engine) (1.1.3)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from duckdb-engine) (24.2)
# Requirement already satisfied: sqlalchemy>=1.3.22 in /usr/local/lib/python3.10/dist-packages (from duckdb-engine) (2.0.36)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine) (3.1.1)

# %%
# %%sql
#
# drop table if exists users;
# CREATE TABLE if not exists users (
#     id INT PRIMARY KEY,
#     name VARCHAR(50),
#     email VARCHAR(100),
#     country VARCHAR(100)
# );
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%capture

# !pip install notebook
# !pip install jupysql
# !pip install duckdb-engine

import duckdb
import pandas as pd

# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False
# %sql duckdb:///::

# %%
# %sql SELECT * FROM read_csv_auto('flights.csv') LIMIT 5;
# Out:
#   FlightDate UniqueCarrier OriginCityName     DestCityName
# 0 1988-01-01            AA   New York, NY  Los Angeles, CA
# 1 1988-01-02            AA   New York, NY  Los Angeles, CA
# 2 1988-01-03            AA   New York, NY  Los Angeles, CA

# %%
# !pip install duckdb
# Out:
# Requirement already satisfied: duckdb in /usr/local/lib/python3.10/dist-packages (1.1.3)

# %%
# %%sql
#
# INSERT INTO users (id, name, email,country)
# VALUES (1, 'John Doe', 'john@example.com','US'),
#        (2, 'Jane Doe', 'jane@example.com','IN'),
#        (3, 'Aang', 'Aang@example.com','US'),
#        (10, 'T',NULL ,NULL);
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
#
# SELECT * FROM users;
# Out:
#    id      name             email country
# 0   1  John Doe  john@example.com      US
# 1   2  Jane Doe  jane@example.com      IN
# 2   3      Aang  Aang@example.com      US
# 3  10         T              None    None

# %%
# %%sql
#
# SELECT *
# FROM users
# WHERE name = 'John Doe';
# Out:
#    id      name             email country
# 0   1  John Doe  john@example.com      US

# %%
# %%sql
# SELECT *
# FROM users
# WHERE country is null
# Out:
#    id name email country
# 0  10    T  None    None

# %%
# %%sql
# SELECT COUNT(*) FROM users;
# Out:
#    count_star()
# 0             4

# %%
# %%sql
# SELECT country, COUNT(*)
# FROM users
# GROUP BY country;
# Out:
#   country  count_star()
# 0      US             2
# 1    None             1
# 2      IN             1

# %%
# %%sql
# SELECT country, COUNT(*)as user_count
# FROM users
# GROUP BY country
# having user_count>1
# Out:
#   country  user_count
# 0      US           2

# %%
# %%sql
# drop view if  exists us_users;
# CREATE VIEW if not exists us_users AS
# SELECT * FROM users WHERE country = 'US';
# select * from us_users;
# Out:
#    id      name             email country
# 0   1  John Doe  john@example.com      US
# 1   3      Aang  Aang@example.com      US

# %%
# %%sql
#
# drop table if exists orders;
# CREATE TABLE if not exists orders (
#     order_id INT PRIMARY KEY,
#     user_id INT,
#     product VARCHAR(50),
#     price int,
#     comments VARCHAR(100)
#     --, FOREIGN KEY (user_id) REFERENCES users(id)
# );
#
# INSERT INTO orders (order_id, user_id, product,price,comments)
# VALUES (101, 1, 'Product A',10,'good product'),
#        (102, 1, 'Product B',20,'bad product'),
#        (103, 3, 'Product C',30,'product good'),
#        (104, 4, 'Product D',null,'product bad');
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
#
# SELECT users.name, orders.product
# FROM users
# INNER JOIN orders ON users.id = orders.user_id;
# Out:
#        name    product
# 0  John Doe  Product B
# 1      Aang  Product C
# 2  John Doe  Product A

# %%
# %%sql
#
# SELECT u.name, o.product
# FROM users u
# INNER JOIN orders o ON u.id = o.user_id;
# Out:
#        name    product
# 0  John Doe  Product B
# 1      Aang  Product C
# 2  John Doe  Product A

# %%
# %%sql
#
# SELECT users.name, orders.product
# FROM users
# LEFT JOIN orders ON users.id = orders.user_id;
# Out:
#        name    product
# 0  John Doe  Product B
# 1      Aang  Product C
# 2  John Doe  Product A
# 3  Jane Doe       None
# 4         T       None

# %%
# %%sql
#
# SELECT users.name, orders.product
# FROM users
# right JOIN orders ON users.id = orders.user_id;
# Out:
#        name    product
# 0  John Doe  Product A
# 1  John Doe  Product B
# 2      Aang  Product C
# 3      None  Product D

# %%
# %%sql
#
# SELECT users.name, orders.product
# FROM users
# cross join  orders
# Out:
#         name    product
# 0   John Doe  Product A
# 1   John Doe  Product B
# 2   John Doe  Product C
# 3   John Doe  Product D
# 4   Jane Doe  Product A
# 5   Jane Doe  Product B
# 6   Jane Doe  Product C
# 7   Jane Doe  Product D
# 8       Aang  Product A
# 9       Aang  Product B
# 10      Aang  Product C
# 11      Aang  Product D
# 12         T  Product A
# 13         T  Product B
# 14         T  Product C
# 15         T  Product D

# %%
# %%sql
#
# SELECT case
#   when product = 'Product A' then 'A'
#   when product = 'Product B' then 'B'
#   when product = 'Product C' then 'C'
#   when product = 'Product D' then 'D'
#   end as modified_product_name,*
#
#  FROM orders
# Out:
#   modified_product_name  order_id  user_id    product  price      comments
# 0                     A       101        1  Product A   10.0  good product
# 1                     B       102        1  Product B   20.0   bad product
# 2                     C       103        3  Product C   30.0  product good
# 3                     D       104        4  Product D    NaN   product bad

# %%
# %%sql
#
# SELECT count(*) as total_count,sum(price) total_price, avg(price) as avg_price, min(price)as min_price, max(price) as max_price
#
#  FROM orders
# Out:
#    total_count  total_price  avg_price  min_price  max_price
# 0            4         60.0       20.0         10         30

# %%
# %%sql
# select distinct user_id from orders
# Out:
#    user_id
# 0        1
# 1        3
# 2        4

# %%
# %%sql
# select count(*),count(distinct user_id) from orders
# Out:
#    count_star()  count(DISTINCT user_id)
# 0             4                        3

# %%
# %%sql
# select * from orders where comments like '%good%'
# Out:
#    order_id  user_id    product  price      comments
# 0       101        1  Product A     10  good product
# 1       103        3  Product C     30  product good

# %%
# %%sql
# select coalesce(price,10) as non_null_price, * from orders
# Out:
#    non_null_price  order_id  user_id    product  price      comments
# 0              10       101        1  Product A   10.0  good product
# 1              20       102        1  Product B   20.0   bad product
# 2              30       103        3  Product C   30.0  product good
# 3              10       104        4  Product D    NaN   product bad

# %%
# %%sql
# select  * from orders order by price desc
# Out:
#    order_id  user_id    product  price      comments
# 0       103        3  Product C   30.0  product good
# 1       102        1  Product B   20.0   bad product
# 2       101        1  Product A   10.0  good product
# 3       104        4  Product D    NaN   product bad

# %%
# %%sql
# select current_date, date_diff('month', DATE '1992-09-15', DATE '1992-11-14') as dd,monthname(DATE '1992-09-20') as mnth,
# DATE '1992-03-22' + INTERVAL 5 DAY as interval
# Out:
#   current_date  dd       mnth   interval
# 0   2024-12-10   2  September 1992-03-27

# %%
# %%sql
# UPDATE users
# SET email = 'john.doe@gmail.com'
# WHERE id = 1;
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# DELETE FROM users WHERE id = 2;
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
input_df = pd.DataFrame.from_dict({"i":[1, 2, 3],
                                  "j":["one", "two", "three"]})
input_df
# Out:
#    i      j
# 0  1    one
# 1  2    two
# 2  3  three

# %%
conn = duckdb.connect(':memory:')
conn.register('input_df', input_df)
output_df = conn.execute("SELECT sum(i) AS total_i FROM input_df").df()
print(output_df)
# Out:
#    total_i
# 0      6.0

# %%
# %%sql
# SELECT * FROM read_csv_auto('flights.csv')
# Out:
#   FlightDate UniqueCarrier OriginCityName     DestCityName
# 0 1988-01-01            AA   New York, NY  Los Angeles, CA
# 1 1988-01-02            AA   New York, NY  Los Angeles, CA
# 2 1988-01-03            AA   New York, NY  Los Angeles, CA

# %%
# !./duckdb -c "DESCRIBE SELECT * FROM read_csv_auto('flights.csv')"
# Out:
# ┌────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │  column_name   │ column_type │  null   │   key   │ default │  extra  │
# │    varchar     │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ FlightDate     │ DATE        │ YES     │         │         │         │
# │ UniqueCarrier  │ VARCHAR     │ YES     │         │         │         │
# │ OriginCityName │ VARCHAR     │ YES     │         │         │         │
# │ DestCityName   │ VARCHAR     │ YES     │         │         │         │
# └────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┘

# %%
# %%sql
# CREATE TABLE if not exists flights_data as select * from read_csv_auto('flights.csv');
# Select * from flights_data
# Out:
#   FlightDate UniqueCarrier OriginCityName     DestCityName
# 0 1988-01-01            AA   New York, NY  Los Angeles, CA
# 1 1988-01-02            AA   New York, NY  Los Angeles, CA
# 2 1988-01-03            AA   New York, NY  Los Angeles, CA

# %%
# %%sql
# Drop table if  exists users;
# Drop table if exists orders;
# CREATE TABLE if not exists users
#                 (id INTEGER ,
#                  name TEXT,
#                  age INTEGER,
#                  city TEXT);
# CREATE TABLE if not exists  orders
#                 (id INTEGER PRIMARY KEY,
#                  user_id INTEGER,
#                  product TEXT,
#                  amount REAL,
#                  comment TEXT
#                  );
# INSERT INTO users (id,name, age, city) VALUES(1,'John Doe', 30, 'New York'),
#                     (2,'Jane Doe', 25, 'Los Angeles'),
#                     (3,'Jim Brown', 35, 'Chicago'),
#                     (4,'Jim Doe', 35, 'Tucson');
# INSERT INTO orders (id,user_id, product, amount,comment) VALUES
# (1,1, 'Product A', 100.0, '{"location" : "Tucson"}'),
#                     (2,2, 'Product B', 200.0,'{"location" : "Phoenix","categories" : ["fashion","clothes"]}'),
#                     (3,1, 'Product C', 150.0,'{"location" : "Tucson","categories" : ["electronics","computers"]}'),
#                     (4,3, 'Product D', 300.0,'{"location" : "Phoenix","categories" : ["grocery"]}')
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
#
#  SELECT name,o.amount
#     FROM orders o
#     join users u
#     on u.id = o.user_id
# Out:
#         name  amount
# 0   John Doe   150.0
# 1   Jane Doe   200.0
# 2  Jim Brown   300.0
# 3   John Doe   100.0

# %%
# %%sql
#
# select user_id, sum(amount)as total from orders group by user_id
# Out:
#    user_id  total
# 0        1  250.0
# 1        2  200.0
# 2        3  300.0

# %%
# %%sql
#
#   Select o.*, round((o.amount/total)*100) as percetage from orders o
#    join (select user_id, sum(amount)as total from orders group by user_id) uo
#    on uo.user_id = o.user_id
# Out:
#    id  user_id    product  amount  \
# 0   1        1  Product A   100.0
# 1   2        2  Product B   200.0
# 2   3        1  Product C   150.0
# 3   4        3  Product D   300.0
#
#                                              comment  percetage
# 0                            {"location" : "Tucson"}       40.0
# 1  {"location" : "Phoenix","categories" : ["fashi...      100.0
# 2  {"location" : "Tucson","categories" : ["electr...       60.0
# 3  {"location" : "Phoenix","categories" : ["groce...      100.0

# %%
# %%sql
#
# SELECT  avg(amount) as avg_amount FROM orders
# Out:
#    avg_amount
# 0       187.5

# %%
# %%sql
#
#  SELECT name,o.amount
#     FROM orders o
#     join users u
#     on u.id = o.user_id
#     where o.amount > (SELECT  avg(amount) as avg_amount FROM orders )
# Out:
#         name  amount
# 0   Jane Doe   200.0
# 1  Jim Brown   300.0

# %%
# %%sql
#
# select * from users where city = 'New York' or city = 'Los Angeles'
# Out:
#    id      name  age         city
# 0   1  John Doe   30     New York
# 1   2  Jane Doe   25  Los Angeles

# %%
# %%sql
#
# select * from users where city = 'New York'  and name= 'John Doe'
# Out:
#    id      name  age      city
# 0   1  John Doe   30  New York

# %%
# %%sql
#
# select * from users where city in ('New York','Los Angeles')
# Out:
#    id      name  age         city
# 0   1  John Doe   30     New York
# 1   2  Jane Doe   25  Los Angeles

# %%
# %%sql
#
# select * from users where id not in (select user_id from orders)
# Out:
#    id     name  age    city
# 0   4  Jim Doe   35  Tucson

# %%
# %%sql
#
# select * from users u where not exists (select user_id from orders o where u.id = o.user_id)
# Out:
#    id     name  age    city
# 0   4  Jim Doe   35  Tucson

# %%
# %%sql
#
# select * from users u where  exists (select user_id from orders o where u.id = o.user_id)
# Out:
#    id       name  age         city
# 0   1   John Doe   30     New York
# 1   2   Jane Doe   25  Los Angeles
# 2   3  Jim Brown   35      Chicago

# %%
# %%sql
#
# Select * from users limit 2
# Out:
#    id      name  age         city
# 0   1  John Doe   30     New York
# 1   2  Jane Doe   25  Los Angeles

# %%
# %%sql
#
# Select * from users order by id desc limit 2
# Out:
#    id       name  age     city
# 0   4    Jim Doe   35   Tucson
# 1   3  Jim Brown   35  Chicago

# %%
# %%sql
#
# Select * from users order by id desc limit 2 offset 0
# Out:
#    id       name  age     city
# 0   4    Jim Doe   35   Tucson
# 1   3  Jim Brown   35  Chicago

# %%
# %%sql
#
# Select * from users order by id desc limit 2 offset 1
# Out:
#    id       name  age         city
# 0   3  Jim Brown   35      Chicago
# 1   2   Jane Doe   25  Los Angeles

# %%
# %%sql
#
# Select * from users order by id desc limit 2 offset 2
# Out:
#    id      name  age         city
# 0   2  Jane Doe   25  Los Angeles
# 1   1  John Doe   30     New York

# %%
# %%sql
#
# Select * from users order by id desc limit 1 offset 1
# Out:
#    id       name  age     city
# 0   3  Jim Brown   35  Chicago

# %%
# %%sql
#
# with user_details as (
#
# select
# id, name, age, case when city = 'New York' then 'NY' else 'Non-NY' end as city
#
#  from
# users
#
# )
#
# Select * from user_details
# Out:
#    id       name  age    city
# 0   1   John Doe   30      NY
# 1   2   Jane Doe   25  Non-NY
# 2   3  Jim Brown   35  Non-NY
# 3   4    Jim Doe   35  Non-NY

# %%
# %%sql
#
# Select id from users
# Out:
#    id
# 0   1
# 1   2
# 2   3
# 3   4

# %%
# %%sql
#
# Select id from users
# union all
# Select id from users
# Out:
#    id
# 0   1
# 1   2
# 2   3
# 3   4
# 4   1
# 5   2
# 6   3
# 7   4

# %%
# %%sql
#
# Select id from users
# union
# Select id from users
# Out:
#    id
# 0   2
# 1   1
# 2   3
# 3   4

# %%
# %%sql
#
#
# Select id from users where id  <=2
# intersect
# Select id from users
# Out:
#    id
# 0   2
# 1   1

# %%
# %%sql
# Select id from users
# EXCEPT
# Select id from users where id  <=2
# Out:
#    id
# 0   3
# 1   4

# %%
# %%sql
# SELECT
# id,comment
#  from orders
# Out:
#    id                                            comment
# 0   1                            {"location" : "Tucson"}
# 1   2  {"location" : "Phoenix","categories" : ["fashi...
# 2   3  {"location" : "Tucson","categories" : ["electr...
# 3   4  {"location" : "Phoenix","categories" : ["groce...

# %%
# %%sql
# SELECT
# id,user_id, product, amount, json_extract_string(comment,'$.location') as location
#  from orders
# Out:
#    id  user_id    product  amount location
# 0   1        1  Product A   100.0   Tucson
# 1   2        2  Product B   200.0  Phoenix
# 2   3        1  Product C   150.0   Tucson
# 3   4        3  Product D   300.0  Phoenix

# %%
# %%sql
#
# SELECT
# id,user_id, product, amount,
# json_extract(comment,'$.categories') as categories ,
# unnest(json_extract(comment,'$.categories'):: VARCHAR[]) as catergory
#  from orders
# Out:
#    id  user_id    product  amount                   categories    catergory
# 0   2        2  Product B   200.0        ["fashion","clothes"]      fashion
# 1   2        2  Product B   200.0        ["fashion","clothes"]      clothes
# 2   3        1  Product C   150.0  ["electronics","computers"]  electronics
# 3   3        1  Product C   150.0  ["electronics","computers"]    computers
# 4   4        3  Product D   300.0                  ["grocery"]      grocery

# %%
# %%sql
# create temp table if not exists users_temp
#                 (id INTEGER ,
#                  name TEXT,
#                  age INTEGER,
#                  city TEXT)
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# select * from users_temp
# Out:
# Empty DataFrame
# Columns: [id, name, age, city]
# Index: []

# %%
import duckdb
from duckdb.typing import VARCHAR

def get_city_type(city):
  data = {'New York': 'NY'}
  return data.get(city,'Non-NY')
duckdb
duckdb.create_function('get_city_type', get_city_type, [VARCHAR], VARCHAR)

# %%
# %%sql
# SELECT *,
#        CASE
#            WHEN LENGTH(city) > 5 THEN 'Large City'
#            ELSE 'Small City'
#        END AS city_type
# FROM users
# Out:
#    id       name  age         city   city_type
# 0   1   John Doe   30     New York  Large City
# 1   2   Jane Doe   25  Los Angeles  Large City
# 2   3  Jim Brown   35      Chicago  Large City
# 3   4    Jim Doe   35       Tucson  Large City

# %%
# %%sql
#
# with RECURSIVE cons_seq as (
#     select 1 as id
#
#     union all
#
#     select id+1 as id from cons_seq where id <5
#
#
# )
#
# select * from cons_seq
# Out:
#    id
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5

# %%
# %%sql
#
# select * ,
# sum(amount) over(order by id) as runnning_total,
# lag(amount,1) over(order by id) as prev_order_amount,
# lag(amount,1) over(partition by user_id order by id) as prev_user_order_amount,
# lead(amount,1) over(order by id) as next_order_amount,
# lead(amount,1) over(partition by user_id order by id) as next_user_order_amount
#
#  FROM orders o
#  order by id
# Out:
#    id  user_id    product  amount  \
# 0   1        1  Product A   100.0
# 1   2        2  Product B   200.0
# 2   3        1  Product C   150.0
# 3   4        3  Product D   300.0
#
#                                              comment  runnning_total  \
# 0                            {"location" : "Tucson"}           100.0
# 1  {"location" : "Phoenix","categories" : ["fashi...           300.0
# 2  {"location" : "Tucson","categories" : ["electr...           450.0
# 3  {"location" : "Phoenix","categories" : ["groce...           750.0
#
#    prev_order_amount  prev_user_order_amount  next_order_amount  \
# 0                NaN                     NaN              200.0
# 1              100.0                     NaN              150.0
# 2              200.0                   100.0              300.0
# 3              150.0                     NaN                NaN
#
#    next_user_order_amount
# 0                   150.0
# 1                     NaN
# 2                     NaN
# 3                     NaN

# %%
# %%sql
# with data as (select id, user_id from orders union all select id , user_id from orders  union all select id , user_id from orders )
#
# Select
# user_id,
# id,
# row_number() over (partition by user_id order by id) as row_no,
# dense_rank() over (partition by user_id order by id) as dr,
# rank() over (partition by user_id order by id) as rnk
#
#  FROM data o
#  where user_id in (1,2)
#  order by user_id,id
# Out:
#    user_id  id  row_no  dr  rnk
# 0        1   1       1   1    1
# 1        1   1       2   1    1
# 2        1   1       3   1    1
# 3        1   3       4   2    4
# 4        1   3       5   2    4
# 5        1   3       6   2    4
# 6        2   2       1   1    1
# 7        2   2       2   1    1
# 8        2   2       3   1    1

# %%
# %%sql
# Drop table if  exists new_users;
# CREATE TABLE if not exists new_users
#                 (p_id INTEGER ,
#                  p_name TEXT,
#                  p_age INTEGER,
#                  p_city TEXT,
#                  state text
#                  );
# INSERT INTO new_users (p_id,p_name, p_age, p_city,state) VALUES(1,'John Doe', 30, 'New York',Null),
#                     (6,'Jane Doe', 25, 'Los Angeles',Null),
#                     (7,'Jim Brown', 35, 'Chicago',Null),
#                     (8,'Jim Doe', 35, 'Tucson','Arizona');
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []
