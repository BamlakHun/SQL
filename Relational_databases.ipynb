# %% [markdown]
# <a href="https://colab.research.google.com/github/BamlakHun/SQL/blob/main/Relational_databases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
